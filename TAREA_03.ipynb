# %% [markdown]
# <a href="https://colab.research.google.com/github/Tamlumiere/starter/blob/main/TAREA_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import seaborn as sns

HABITO  = pd.read_csv ('/content/drive/MyDrive/Colab Notebooks/TAREA 3 (1)/HABITO ALIMENTICIO TAREA 3.csv')

HABITO.head()
# Out:
#   DIAS;CALORIAS CONSUMIDAS;CALORIAS QUEMADAS;PROTEINAS;GRASAS;CARBOHIDRATOS;FRUTAS;VERDURAS
# 0                         LUNES;1108;0;62;31;150;3;3
# 1                     MARTES;1722;150;122;62;169;3;2
# 2                    MIERCOLES;1622;90;88;86;128;2;3
# 3                      JUEVES;1630;120;80;50;170;4;2
